# %% [markdown]
# <a href="https://colab.research.google.com/github/Danielperez471/Simulacion/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simulacion
# ## Unidad 2
# ### Practica 1.Generacion de numeros aleatorios por el metodo de centros al cuadrado
# ##Profesor: Rodriguez Rivas Jose Gabriel
# ##Alumno: Perez Macias Daniel Alonso

# %%
##Semilla Inicial
semilla=2005
n=4
resultados=[]
iteraciones = 100
resultados=[]

for _ in range(iteraciones):
    #Elevar la semilla al cuadrado
    cuadrado=str(semilla**2).zfill(2 * n) #Agregar los espacios necesarios
    #Extraer los digitos centrales
    inicio=(len(cuadrado)-n)//2
    semilla=int(cuadrado[inicio:inicio + n])
    resultados.append(semilla)

    #Imprimir los resultados
    for i, numero in enumerate(resultados, 1):
        print (f"Numero Aleatorio {i}:{numero}")
# Out:
# Numero Aleatorio1:200
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio60:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio60:5600
# Numero Aleatorio61:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio60:5600
# Numero Aleatorio61:3600
# Numero Aleatorio62:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio60:5600
# Numero Aleatorio61:3600
# Numero Aleatorio62:9600
# Numero Aleatorio63:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# ...
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio60:5600
# Numero Aleatorio61:3600
# Numero Aleatorio62:9600
# Numero Aleatorio63:1600
# Numero Aleatorio64:5600
# Numero Aleatorio65:3600
# Numero Aleatorio66:9600
# Numero Aleatorio67:1600
# Numero Aleatorio68:5600
# Numero Aleatorio69:3600
# Numero Aleatorio70:9600
# Numero Aleatorio71:1600
# Numero Aleatorio72:5600
# Numero Aleatorio73:3600
# Numero Aleatorio74:9600
# Numero Aleatorio75:1600
# Numero Aleatorio76:5600
# Numero Aleatorio77:3600
# Numero Aleatorio78:9600
# Numero Aleatorio79:1600
# Numero Aleatorio80:5600
# Numero Aleatorio81:3600
# Numero Aleatorio82:9600
# Numero Aleatorio83:1600
# Numero Aleatorio84:5600
# Numero Aleatorio85:3600
# Numero Aleatorio86:9600
# Numero Aleatorio87:1600
# Numero Aleatorio88:5600
# Numero Aleatorio89:3600
# Numero Aleatorio90:9600
# Numero Aleatorio91:1600
# Numero Aleatorio92:5600
# Numero Aleatorio93:3600
# Numero Aleatorio94:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio60:5600
# Numero Aleatorio61:3600
# Numero Aleatorio62:9600
# Numero Aleatorio63:1600
# Numero Aleatorio64:5600
# Numero Aleatorio65:3600
# Numero Aleatorio66:9600
# Numero Aleatorio67:1600
# Numero Aleatorio68:5600
# Numero Aleatorio69:3600
# Numero Aleatorio70:9600
# Numero Aleatorio71:1600
# Numero Aleatorio72:5600
# Numero Aleatorio73:3600
# Numero Aleatorio74:9600
# Numero Aleatorio75:1600
# Numero Aleatorio76:5600
# Numero Aleatorio77:3600
# Numero Aleatorio78:9600
# Numero Aleatorio79:1600
# Numero Aleatorio80:5600
# Numero Aleatorio81:3600
# Numero Aleatorio82:9600
# Numero Aleatorio83:1600
# Numero Aleatorio84:5600
# Numero Aleatorio85:3600
# Numero Aleatorio86:9600
# Numero Aleatorio87:1600
# Numero Aleatorio88:5600
# Numero Aleatorio89:3600
# Numero Aleatorio90:9600
# Numero Aleatorio91:1600
# Numero Aleatorio92:5600
# Numero Aleatorio93:3600
# Numero Aleatorio94:9600
# Numero Aleatorio95:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio60:5600
# Numero Aleatorio61:3600
# Numero Aleatorio62:9600
# Numero Aleatorio63:1600
# Numero Aleatorio64:5600
# Numero Aleatorio65:3600
# Numero Aleatorio66:9600
# Numero Aleatorio67:1600
# Numero Aleatorio68:5600
# Numero Aleatorio69:3600
# Numero Aleatorio70:9600
# Numero Aleatorio71:1600
# Numero Aleatorio72:5600
# Numero Aleatorio73:3600
# Numero Aleatorio74:9600
# Numero Aleatorio75:1600
# Numero Aleatorio76:5600
# Numero Aleatorio77:3600
# Numero Aleatorio78:9600
# Numero Aleatorio79:1600
# Numero Aleatorio80:5600
# Numero Aleatorio81:3600
# Numero Aleatorio82:9600
# Numero Aleatorio83:1600
# Numero Aleatorio84:5600
# Numero Aleatorio85:3600
# Numero Aleatorio86:9600
# Numero Aleatorio87:1600
# Numero Aleatorio88:5600
# Numero Aleatorio89:3600
# Numero Aleatorio90:9600
# Numero Aleatorio91:1600
# Numero Aleatorio92:5600
# Numero Aleatorio93:3600
# Numero Aleatorio94:9600
# Numero Aleatorio95:1600
# Numero Aleatorio96:5600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio60:5600
# Numero Aleatorio61:3600
# Numero Aleatorio62:9600
# Numero Aleatorio63:1600
# Numero Aleatorio64:5600
# Numero Aleatorio65:3600
# Numero Aleatorio66:9600
# Numero Aleatorio67:1600
# Numero Aleatorio68:5600
# Numero Aleatorio69:3600
# Numero Aleatorio70:9600
# Numero Aleatorio71:1600
# Numero Aleatorio72:5600
# Numero Aleatorio73:3600
# Numero Aleatorio74:9600
# Numero Aleatorio75:1600
# Numero Aleatorio76:5600
# Numero Aleatorio77:3600
# Numero Aleatorio78:9600
# Numero Aleatorio79:1600
# Numero Aleatorio80:5600
# Numero Aleatorio81:3600
# Numero Aleatorio82:9600
# Numero Aleatorio83:1600
# Numero Aleatorio84:5600
# Numero Aleatorio85:3600
# Numero Aleatorio86:9600
# Numero Aleatorio87:1600
# Numero Aleatorio88:5600
# Numero Aleatorio89:3600
# Numero Aleatorio90:9600
# Numero Aleatorio91:1600
# Numero Aleatorio92:5600
# Numero Aleatorio93:3600
# Numero Aleatorio94:9600
# Numero Aleatorio95:1600
# Numero Aleatorio96:5600
# Numero Aleatorio97:3600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio60:5600
# Numero Aleatorio61:3600
# Numero Aleatorio62:9600
# Numero Aleatorio63:1600
# Numero Aleatorio64:5600
# Numero Aleatorio65:3600
# Numero Aleatorio66:9600
# Numero Aleatorio67:1600
# Numero Aleatorio68:5600
# Numero Aleatorio69:3600
# Numero Aleatorio70:9600
# Numero Aleatorio71:1600
# Numero Aleatorio72:5600
# Numero Aleatorio73:3600
# Numero Aleatorio74:9600
# Numero Aleatorio75:1600
# Numero Aleatorio76:5600
# Numero Aleatorio77:3600
# Numero Aleatorio78:9600
# Numero Aleatorio79:1600
# Numero Aleatorio80:5600
# Numero Aleatorio81:3600
# Numero Aleatorio82:9600
# Numero Aleatorio83:1600
# Numero Aleatorio84:5600
# Numero Aleatorio85:3600
# Numero Aleatorio86:9600
# Numero Aleatorio87:1600
# Numero Aleatorio88:5600
# Numero Aleatorio89:3600
# Numero Aleatorio90:9600
# Numero Aleatorio91:1600
# Numero Aleatorio92:5600
# Numero Aleatorio93:3600
# Numero Aleatorio94:9600
# Numero Aleatorio95:1600
# Numero Aleatorio96:5600
# Numero Aleatorio97:3600
# Numero Aleatorio98:9600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio60:5600
# Numero Aleatorio61:3600
# Numero Aleatorio62:9600
# Numero Aleatorio63:1600
# Numero Aleatorio64:5600
# Numero Aleatorio65:3600
# Numero Aleatorio66:9600
# Numero Aleatorio67:1600
# Numero Aleatorio68:5600
# Numero Aleatorio69:3600
# Numero Aleatorio70:9600
# Numero Aleatorio71:1600
# Numero Aleatorio72:5600
# Numero Aleatorio73:3600
# Numero Aleatorio74:9600
# Numero Aleatorio75:1600
# Numero Aleatorio76:5600
# Numero Aleatorio77:3600
# Numero Aleatorio78:9600
# Numero Aleatorio79:1600
# Numero Aleatorio80:5600
# Numero Aleatorio81:3600
# Numero Aleatorio82:9600
# Numero Aleatorio83:1600
# Numero Aleatorio84:5600
# Numero Aleatorio85:3600
# Numero Aleatorio86:9600
# Numero Aleatorio87:1600
# Numero Aleatorio88:5600
# Numero Aleatorio89:3600
# Numero Aleatorio90:9600
# Numero Aleatorio91:1600
# Numero Aleatorio92:5600
# Numero Aleatorio93:3600
# Numero Aleatorio94:9600
# Numero Aleatorio95:1600
# Numero Aleatorio96:5600
# Numero Aleatorio97:3600
# Numero Aleatorio98:9600
# Numero Aleatorio99:1600
# Numero Aleatorio1:200
# Numero Aleatorio2:400
# Numero Aleatorio3:1600
# Numero Aleatorio4:5600
# Numero Aleatorio5:3600
# Numero Aleatorio6:9600
# Numero Aleatorio7:1600
# Numero Aleatorio8:5600
# Numero Aleatorio9:3600
# Numero Aleatorio10:9600
# Numero Aleatorio11:1600
# Numero Aleatorio12:5600
# Numero Aleatorio13:3600
# Numero Aleatorio14:9600
# Numero Aleatorio15:1600
# Numero Aleatorio16:5600
# Numero Aleatorio17:3600
# Numero Aleatorio18:9600
# Numero Aleatorio19:1600
# Numero Aleatorio20:5600
# Numero Aleatorio21:3600
# Numero Aleatorio22:9600
# Numero Aleatorio23:1600
# Numero Aleatorio24:5600
# Numero Aleatorio25:3600
# Numero Aleatorio26:9600
# Numero Aleatorio27:1600
# Numero Aleatorio28:5600
# Numero Aleatorio29:3600
# Numero Aleatorio30:9600
# Numero Aleatorio31:1600
# Numero Aleatorio32:5600
# Numero Aleatorio33:3600
# Numero Aleatorio34:9600
# Numero Aleatorio35:1600
# Numero Aleatorio36:5600
# Numero Aleatorio37:3600
# Numero Aleatorio38:9600
# Numero Aleatorio39:1600
# Numero Aleatorio40:5600
# Numero Aleatorio41:3600
# Numero Aleatorio42:9600
# Numero Aleatorio43:1600
# Numero Aleatorio44:5600
# Numero Aleatorio45:3600
# Numero Aleatorio46:9600
# Numero Aleatorio47:1600
# Numero Aleatorio48:5600
# Numero Aleatorio49:3600
# Numero Aleatorio50:9600
# Numero Aleatorio51:1600
# Numero Aleatorio52:5600
# Numero Aleatorio53:3600
# Numero Aleatorio54:9600
# Numero Aleatorio55:1600
# Numero Aleatorio56:5600
# Numero Aleatorio57:3600
# Numero Aleatorio58:9600
# Numero Aleatorio59:1600
# Numero Aleatorio60:5600
# Numero Aleatorio61:3600
# Numero Aleatorio62:9600
# Numero Aleatorio63:1600
# Numero Aleatorio64:5600
# Numero Aleatorio65:3600
# Numero Aleatorio66:9600
# Numero Aleatorio67:1600
# Numero Aleatorio68:5600
# Numero Aleatorio69:3600
# Numero Aleatorio70:9600
# Numero Aleatorio71:1600
# Numero Aleatorio72:5600
# Numero Aleatorio73:3600
# Numero Aleatorio74:9600
# Numero Aleatorio75:1600
# Numero Aleatorio76:5600
# Numero Aleatorio77:3600
# Numero Aleatorio78:9600
# Numero Aleatorio79:1600
# Numero Aleatorio80:5600
# Numero Aleatorio81:3600
# Numero Aleatorio82:9600
# Numero Aleatorio83:1600
# Numero Aleatorio84:5600
# Numero Aleatorio85:3600
# Numero Aleatorio86:9600
# Numero Aleatorio87:1600
# Numero Aleatorio88:5600
# Numero Aleatorio89:3600
# Numero Aleatorio90:9600
# Numero Aleatorio91:1600
# Numero Aleatorio92:5600
# Numero Aleatorio93:3600
# Numero Aleatorio94:9600
# Numero Aleatorio95:1600
# Numero Aleatorio96:5600
# Numero Aleatorio97:3600
# Numero Aleatorio98:9600
# Numero Aleatorio99:1600
# Numero Aleatorio100:5600

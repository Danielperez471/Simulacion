# %% [markdown]
# <a href="https://colab.research.google.com/github/Danielperez471/Simulacion/blob/main/UNIDAD3/Practica2_Distribusion_exponencial_Tiempos_de_Inactividad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DISTRIBUCION EXPONENCIAL - TIEMPOS DE INACTIVIDAD.
# ###La distribución exponencial es una distribución de probabilidad continua que se utiliza para modelar el tiempo entre eventos, donde los eventos ocurren de manera independiente a una tasa constante.
# ###Facilitador: José Gabriel Rodríguez Rivas
# ###Alumno: Daniel Alonso Perez Macias
#
# El método de la transformada inversa es utilizada para generar variables aleatorias que sigan distribuciones específicas, como la distribución exponencial utilizada en este caso para modelar los tiempos de inactividad de un brazo de robot de soldadura. Permite simular fenómenos de mantenimiento y fallos aleatorios en sistemas industriales, lo que es fundamental para la planificación de la producción y la gestión de recursos en fábricas.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetro de la distribución exponencial (tasa de inactividad)
lambda_inactividad = 1 / 10  # Tiempo promedio de inactividad = 10 minutos

# Función para generar un tiempo de inactividad
def generar_tiempo_inactividad(lambda_inactividad):
    u = np.random.uniform(0, 1)  # Generar número aleatorio uniforme
    # Aplicar transformada inversa
    tiempo_inactividad = -1 / lambda_inactividad * np.log(1 - u)
    return tiempo_inactividad

# Generar 100 tiempos de inactividad
tiempos_inactividad = [generar_tiempo_inactividad(lambda_inactividad)
                       for _ in range(100)]

# Mostrar los tiempos de inactividad generados
print("Tiempos de inactividad generados:", tiempos_inactividad)

# Graficar los tiempos de inactividad simulados
plt.hist(tiempos_inactividad, bins=10, edgecolor='black', alpha=0.7)
plt.title('Distribución de Tiempos de Inactividad Simulados (Exponencial)')
plt.xlabel('Tiempo de inactividad (minutos)')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# Tiempos de inactividad generados: [np.float64(9.346165840818015), np.float64(4.615596988931382), np.float64(10.965907930687834), np.float64(3.7556604991190383), np.float64(0.46239486497675786), np.float64(1.456746304946466), np.float64(23.904383909000973), np.float64(9.663645881217835), np.float64(12.030566970386257), np.float64(40.031252864107245), np.float64(21.472285166900914), np.float64(1.4432300796452557), np.float64(23.44771589772357), np.float64(13.717137073025246), np.float64(2.285269382731677), np.float64(7.544007613649811), np.float64(0.36060742064916396), np.float64(41.795791730658266), np.float64(15.670318357899715), np.float64(6.676577692507789), np.float64(3.1092498742795893), np.float64(23.48771206971979), np.float64(1.0656388069206142), np.float64(6.923580739057872), np.float64(7.112394776733467), np.float64(24.088551078233994), np.float64(0.6299622864134768), np.float64(13.503085130543122), np.float64(12.037184410053225), np.float64(8.430785622214035), np.float64(16
# ...

# %% [markdown]
# #CONCLUSION
#
# La simulación de los tiempos de inactividad para un brazo de robot de soldadura en una fábrica de vehículos nos proporciona información valiosa para la planificación y optimización del sistema de producción. Algunos puntos clave a destacar son:
#
# Interpretación de los tiempos de inactividad: Los tiempos generados varían desde valores cercanos a cero hasta tiempos largos superiores a 40 minutos. Esto refleja posibles escenarios en los que el brazo del robot puede experimentar breves pausas operativas o fallos más prolongados. La variabilidad observada es consistente con la naturaleza aleatoria de los tiempos entre fallos en sistemas industriales.
#
# Tasa constante de fallos: Asumir una distribución exponencial implica que la probabilidad de ocurrencia de un fallo es constante a lo largo del tiempo. Esto se ajusta bien a contextos donde los fallos son inesperados y no dependen del tiempo transcurrido desde el último evento.
#
# Impacto operativo: Conocer los tiempos promedio y los máximos posibles de inactividad permite a los responsables de producción prever recursos para mantenimiento, reducir tiempos de reparación y minimizar pérdidas de productividad. Si los tiempos de inactividad son muy elevados, se podría considerar la implementación de mantenimiento preventivo para disminuir la frecuencia de fallos.
#
# Aplicación práctica: Estos datos pueden servir para ajustar políticas de mantenimiento, analizar costos asociados con tiempos muertos y mejorar la eficiencia operativa del sistema de soldadura. Además, se pueden utilizar para crear simulaciones más complejas y evaluar la capacidad del sistema bajo diferentes escenarios.
